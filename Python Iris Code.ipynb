# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
pwd
# Out:
# 'C:\\Users\\The Emoji Girl'

# %%
df = pd.read_csv("IrisDataset.csv") #loading the dataset

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop(["Id"], axis = 1)

# %%
df.shape
# Out:
# (150, 5)

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#DATA PREPROCESSING
#dealing with missing values
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe(include = "all") #statistical summary
# Out:
#         SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# count      150.000000    150.000000     150.000000    150.000000          150
# unique            NaN           NaN            NaN           NaN            3
# top               NaN           NaN            NaN           NaN  Iris-setosa
# freq              NaN           NaN            NaN           NaN           50
# mean         5.843333      3.054000       3.758667      1.198667          NaN
# std          0.828066      0.433594       1.764420      0.763161          NaN
# min          4.300000      2.000000       1.000000      0.100000          NaN
# 25%          5.100000      2.800000       1.600000      0.300000          NaN
# 50%          5.800000      3.000000       4.350000      1.300000          NaN
# 75%          6.400000      3.300000       5.100000      1.800000          NaN
# max          7.900000      4.400000       6.900000      2.500000          NaN

# %%
df[df.duplicated()]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (147, 5)

# %%
#DATA VISUALIZATION - to gain insights
sns.scatterplot(x = "SepalLengthCm",
                y = "SepalWidthCm",
                data = df,
                hue = "Species")
plt.legend(loc = 0)

# %%
sns.scatterplot(x = "PetalLengthCm",
                y = "PetalWidthCm",
                data = df,
                hue = "Species")
plt.legend(loc = 0)

# %%
sns.pairplot(df, hue = "Species")

# %%
sns.boxplot(y = "SepalWidthCm",data = df)
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.boxplot(y = "SepalLengthCm",data = df)
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
sns.boxplot(y = "PetalLengthCm",data = df)
# Out:
# <Axes: ylabel='PetalLengthCm'>

# %%
sns.boxplot(y = "PetalWidthCm",data = df)
# Out:
# <Axes: ylabel='PetalWidthCm'>

# %%
sns.boxplot(y = "PetalWidthCm", data = df, x = "Species")
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.boxplot(y = "PetalLengthCm", data = df, x = "Species")
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
fig,ax = plt.subplots(2,2,figsize=(10,10))
sns.boxplot(x = "Species", y = "SepalWidthCm", data = df, ax = ax[0][0])
ax[0][0].set_title("SepalWidth")

sns.boxplot(x = "Species", y = "SepalLengthCm", data = df, ax = ax[0][1])
ax[0][1].set_title("SepalLength")

sns.boxplot(x = "Species", y = "PetalWidthCm", data = df, ax = ax[1][0])
ax[1][0].set_title("PetalWidth")

sns.boxplot(x = "Species", y = "PetalLengthCm", data = df, ax = ax[1][1])
ax[1][1].set_title("PetalLength")
# Out:
# Text(0.5, 1.0, 'PetalLength')

# %%
fig,ax = plt.subplots(2,2,figsize=(10,10))
sns.barplot(x = "Species", y = "SepalWidthCm", data = df, ax = ax[0][0])
ax[0][0].set_title("SepalWidth")

sns.barplot(x = "Species", y = "SepalLengthCm", data = df, ax = ax[0][1])
ax[0][1].set_title("SepalLength")

sns.barplot(x = "Species", y = "PetalWidthCm", data = df, ax = ax[1][0])
ax[1][0].set_title("PetalWidth")

sns.barplot(x = "Species", y = "PetalLengthCm", data = df, ax = ax[1][1])
ax[1][1].set_title("PetalLength")
# Out:
# Text(0.5, 1.0, 'PetalLength')

# %%
#dealing with outliers
def percentile(x) :
    Q1, Q3 = np.percentile(x, [25, 75])
    IQR = Q3 - Q1
    Upper = Q3 + 1.5*IQR
    Lower = Q1 - 1.5*IQR
    return Upper,Lower

# %%
Upper_bound, Lower_bound = percentile(df["SepalWidthCm"])

# %%
Upper_bound
# Out:
# 4.05

# %%
Lower_bound
# Out:
# 2.05

# %%
mask1 = df["SepalWidthCm"] <= Upper_bound
mask2 = df["SepalWidthCm"] >= Lower_bound
mask = mask1 & mask2
df = df[mask]

# %%
sns.boxplot(y = "SepalWidthCm", data = df)
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
# seperating features and target
x = df.drop(["Species"], axis = 1)
y = df[["Species"]]

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
#dealing with skewness
x.skew()
# Out:
# SepalLengthCm    0.254691
# SepalWidthCm     0.133521
# PetalLengthCm   -0.344711
# PetalWidthCm    -0.158025
# dtype: float64

# %%
x.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2

# %%
x.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.113268       0.879015      0.821715
# SepalWidthCm       -0.113268      1.000000      -0.396539     -0.328102
# PetalLengthCm       0.879015     -0.396539       1.000000      0.960785
# PetalWidthCm        0.821715     -0.328102       0.960785      1.000000

# %%
sns.heatmap(x.corr(),annot = True)
# Out:
# <Axes: >

# %%
#splitting train & test data
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,stratify = y, random_state = 42)

# %%
X_train.head(2)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 83            6.0           2.7            5.1           1.6
# 12            4.8           3.0            1.4           0.1

# %%
X_train.shape
# Out:
# (114, 4)

# %%
X_test.head(2)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 110            6.5           3.2            5.1           2.0
# 146            6.3           2.5            5.0           1.9

# %%
X_test.shape
# Out:
# (29, 4)

# %%
#implementing KNN algorithm
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier() #creating the model

# %%
model.fit(X_train,y_train) #training the model
# Out:
# KNeighborsClassifier()

# %%
ypred = model.predict(X_test) #evaluating the model

# %%
ypred
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,ypred) #checking the accuracy
# Out:
# 0.9655172413793104

# %%
#scaling the data
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
model_1 = KNeighborsClassifier() # n = 5
model_1.fit(X_train_scaled,y_train)
ypred_1 = model_1.predict(X_test_scaled)

# %%
ypred_1
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypred_1)
# Out:
# 0.9310344827586207

# %%
for i in range(3,30,2):
    model_i = KNeighborsClassifier(n_neighbors=i)
    model_i.fit(X_train_scaled, y_train)
    ypred_i = model_i.predict(X_test_scaled)
    a = accuracy_score(y_test, ypred_i)
    print (f" (For k = {i}, the accuracy is {a})")
# Out:
#  (For k = 3, the accuracy is 0.9310344827586207)
#  (For k = 5, the accuracy is 0.9310344827586207)
#  (For k = 7, the accuracy is 1.0)
#  (For k = 9, the accuracy is 1.0)
#  (For k = 11, the accuracy is 0.9655172413793104)
#  (For k = 13, the accuracy is 0.9655172413793104)
#  (For k = 15, the accuracy is 0.9655172413793104)
#  (For k = 17, the accuracy is 0.9655172413793104)
#  (For k = 19, the accuracy is 0.9655172413793104)
#  (For k = 21, the accuracy is 0.9310344827586207)
#  (For k = 23, the accuracy is 0.9655172413793104)
#  (For k = 25, the accuracy is 0.9655172413793104)
#  (For k = 27, the accuracy is 0.9655172413793104)
#  (For k = 29, the accuracy is 0.9310344827586207)

# %%
model_final = KNeighborsClassifier(n_neighbors = 9)

# %%
model_final.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
ypred_final = model_final.predict(X_test_scaled)

# %%
accuracy_score(y_test,ypred_final)
# Out:
# 1.0

# %%
#serialization/dumping - saving the model in disk
import joblib

# %%
joblib.dump(model_final,"KNNIris.pkl")
# Out:
# ['KNNIris.pkl']

# %%
load_model = joblib.load("KNNIris.pkl") #loading the model from disk

# %%
ypredict = load_model.predict(X_test_scaled)

# %%
ypredict
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypredict)
# Out:
# 1.0

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gb = GaussianNB()

# %%
gb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
ypred2 = gb.predict(X_test)

# %%
ypred2
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype='<U15')

# %%
accuracy_score(y_test,ypred2)
# Out:
# 0.9310344827586207

# %%
scalar2 = StandardScaler()

# %%
X_train_scaled2 = scalar2.fit_transform(X_train)
X_test_scaled2 = scalar2.transform(X_test)

# %%
model_2 = GaussianNB()

# %%
model_2.fit(X_train_scaled2,y_train)
# Out:
# GaussianNB()

# %%
ypred_2 = model_2.predict(X_test_scaled2)

# %%
ypred_2
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype='<U15')

# %%
accuracy_score(y_test,ypred_2)
# Out:
# 0.9310344827586207

# %%
joblib.dump(model_2,"NaiveBayesIris.pkl")
# Out:
# ['NaiveBayesIris.pkl']

# %%
load_gb = joblib.load("NaiveBayesIris.pkl")

# %%
ypredict2 = load_gb.predict(X_test_scaled2)

# %%
ypredict2
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype='<U15')

# %%
accuracy_score(y_test,ypredict2)
# Out:
# 0.9310344827586207

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred3 = dtree.predict(X_test)

# %%
ypred3
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypred3)
# Out:
# 0.9655172413793104

# %%
scalar3 = StandardScaler()

# %%
X_train_scaled3 = scalar3.fit_transform(X_train)
X_test_scaled3 = scalar3.transform(X_test)

# %%
model_3 = DecisionTreeClassifier()

# %%
model_3.fit(X_train_scaled3,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred_3 = model_3.predict(X_test_scaled3)

# %%
ypred_3
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypred_3)
# Out:
# 0.9310344827586207

# %%
joblib.dump(model_3,"DecisionTreeIris.pkl")
# Out:
# ['DecisionTreeIris.pkl']

# %%
load_dtree = joblib.load("DecisionTreeIris.pkl")

# %%
ypredict3 = load_dtree.predict(X_test_scaled3)

# %%
ypredict3
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypredict3)
# Out:
# 0.9310344827586207

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
ypred4 = svm.predict(X_test)

# %%
ypred4
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypred4)
# Out:
# 1.0

# %%
scalar4 = StandardScaler()

# %%
X_train_scaled4 = scalar4.fit_transform(X_train)
X_test_scaled4 = scalar4.transform(X_test)

# %%
model_4 = SVC()

# %%
model_4.fit(X_train_scaled4,y_train)
# Out:
# SVC()

# %%
ypred_4 = model_4.predict(X_test_scaled4)

# %%
ypred_4
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypred_4)
# Out:
# 1.0

# %%
joblib.dump(model_4,"SVMIris.pkl")
# Out:
# ['SVMIris.pkl']

# %%
load_SVM = joblib.load("SVMIris.pkl")

# %%
ypredict4 = load_SVM.predict(X_test_scaled4)

# %%
ypredict4
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
accuracy_score(y_test,ypredict4)
# Out:
# 1.0

# %%
import tkinter as tk
import numpy as np

# Function to handle prediction and display result in the Tkinter window
def predict_species():
    try:
        # Get input values from the user
        sepal_length = float(entry_sepal_length.get())
        sepal_width = float(entry_sepal_width.get())
        petal_length = float(entry_petal_length.get())
        petal_width = float(entry_petal_width.get())

        # Create the input array and perform scaling
        x_new = np.array([[sepal_length, sepal_width, petal_length, petal_width]])
        x_new_scaled = scalar.transform(x_new)

        # Predict the class of the iris flower
        prediction = model_final.predict(x_new_scaled)

        # Display the result in the result label
        result_label.config(text=f"Predicted Species: {prediction[0]}")

    except ValueError:
        result_label.config(text="Invalid Input! Please enter valid numbers.")

# Initialize the main window
root = tk.Tk()
root.title("Iris Flower Classification")
root.geometry("600x400")
root.configure(bg="#f0f0f0")

# Title label
label_title = tk.Label(root, text="Iris Flower Classification", font=("Arial", 16, "bold"), bg="#f0f0f0", fg="#333")
label_title.pack(pady=10)

# Input fields
frame_inputs = tk.Frame(root, bg="#f0f0f0")
frame_inputs.pack(pady=10)

labels = ["Sepal Length (cm):", "Sepal Width (cm):", "Petal Length (cm):", "Petal Width (cm):"]
entries = []

# Dynamically create labels and entry fields
for i, text in enumerate(labels):
    label = tk.Label(frame_inputs, text=text, font=("Arial", 12), bg="#f0f0f0")
    label.grid(row=i, column=0, padx=10, pady=5, sticky="w")

    entry = tk.Entry(frame_inputs, font=("Arial", 12))
    entry.grid(row=i, column=1, padx=10, pady=5)
    entries.append(entry)

# Assign entries to variables for readability
entry_sepal_length, entry_sepal_width, entry_petal_length, entry_petal_width = entries

# Predict button
btn_predict = tk.Button(root, text="Predict Species", font=("Arial", 14), bg="#4CAF50", fg="white", command=predict_species)
btn_predict.pack(pady=20)

# Label to display the prediction result
result_label = tk.Label(root, text="", font=("Arial", 14), bg="#f0f0f0", fg="blue")
result_label.pack(pady=10)

# Start the Tkinter event loop
root.mainloop()
